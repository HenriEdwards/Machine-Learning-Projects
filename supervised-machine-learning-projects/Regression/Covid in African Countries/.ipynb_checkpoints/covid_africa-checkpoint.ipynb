# %% [markdown]
# ### Exploring Covid in Africa

# %% [markdown]
# <a id="cont"></a>
#
# ### Table of Contents
#
# <a href=#one>1. Packages</a>

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning) 

import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import sklearn

# %%
data = pd.read_csv('covid_africa.csv', index_col=0)

# %%
data.head(5)
# Out:
#                Total Cases  Total Deaths  Total Recovered  Active Cases  \
# Country/Other
# Algeria             265739          6874         178335.0       80530.0
# Angola               99194          1900          97149.0         145.0
# Benin                26952           163          25506.0        1283.0
# Botswana            305859          2688         303026.0         145.0
# Burkina Faso         20853           382          20439.0          32.0
#
#                Tot Cases/ 1M pop  Deaths/ 1M pop  Total Tests  Tests/ 1M pop  \
# Country/Other
# Algeria                     5870             152     230861.0         5100.0
# Angola                      2859              55    1499795.0        43230.0
# Benin                       2124              13     604310.0        47618.0
# Botswana                  125531            1103    2026898.0       831880.0
# Burkina Faso                 951              17     248995.0        11355.0
#
#                Population
# ...

# %%
data.describe()
# Out:
#         Total Cases   Total Deaths  Total Recovered  Active Cases  \
# count  5.400000e+01      54.000000     5.000000e+01     50.000000
# mean   2.116154e+05    4675.370370     1.928952e+05   8442.300000
# std    5.404438e+05   14310.867875     5.323413e+05  19540.534398
# min    5.948000e+03      38.000000     7.730000e+02      1.000000
# 25%    2.165950e+04     278.250000     1.547725e+04     39.250000
# 50%    5.733550e+04     983.500000     4.910500e+04    673.000000
# 75%    1.633135e+05    3029.250000     1.581335e+05   3666.750000
# max    3.741230e+06  100147.000000     3.627594e+06  82778.000000
#
#        Tot Cases/ 1M pop  Deaths/ 1M pop   Total Tests  Tests/ 1M pop  \
# count          54.000000       54.000000  5.100000e+01      51.000000
# mean        23966.555556      304.222222  1.938529e+06  158502.568627
# std         61163.285804      511.350696  3.743918e+06  215620.789351
# min           344.000000        3.000000  2.369300e+04    5100.000000
# ...
